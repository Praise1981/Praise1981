# %%
import os
import shutil
import glob

# Print the current working directory
print("Current Working Directory: ", os.getcwd())
# Out:
# Current Working Directory:  /home/admin/Documents/Lillian

# %%
# Get the current working directory
cwd = os.getcwd()

# %%
# Construct the path to the train and validation datasets
train_path = os.path.join(cwd, 'dataset', 'images', 'train')
val_path = os.path.join(cwd, 'dataset', 'images', 'val')

# %%
# Print out the paths to check if they're correct
print(f"Training path: {train_path}")
print(f"Validation path: {val_path}")
# Out:
# Training path: /home/admin/Documents/Lillian/dataset/images/train
# Validation path: /home/admin/Documents/Lillian/dataset/images/val

# %%
# List everything in the current directory
print(os.listdir())
# Out:
# ['dataset', 'Lilian.ipynb', 'Lilian_project.ipynb', 'traced_model.pt', 'external_data', 'runs', 'yolov7', 'guide.docx', '.ipynb_checkpoints']

# %%
os.chdir('yolov7')

# %%
# Run training command
# !python train.py --img 640 --batch 16 --epochs 50 --data data.yaml --weights yolov7.pt --cache
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
# autoanchor: Analyzing anchors... anchors/target = 4.05, Best Possible Recall (BPR) = 1.0000
#                  all          10         105      0.0155      0.0286    0.000509    0.000124
#                  all          10         105      0.0199       0.019     0.00048    0.000129
#                  all          10         105       0.024       0.019    0.000674    0.000146
#                  all          10         105      0.0245       0.019    0.000661    8.36e-05
#                  all          10         105      0.0112      0.0381      0.0012    0.000179
#                  all          10         105      0.0321      0.0286     0.00219    0.000379
#                  all          10         105      0.0343      0.0286     0.00321    0.000592
#                  all          10         105      0.0222       0.114     0.00498    0.000916
# ...

# %%
# !python detect.py --weights best_model/best.pt --img 640 --conf 0.25 --source "/home/admin/Documents/Lillian/dataset/images/val"
# Out:
# Namespace(weights=['best_model/best.pt'], source='/home/admin/Documents/Lillian/dataset/images/val', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.3.0+cu121 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36479926 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /home/admin/anaconda3/envs/cv/lib/python3.10/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
# ...

# %%
# !python detect.py --weights best_model/best.pt --img 640 --conf 0.25 --source /home/admin/Documents/Lillian/external_data/Tokyo.mp4
# Out:
# Namespace(weights=['best_model/best.pt'], source='/home/admin/Documents/Lillian/external_data/Tokyo.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.3.0+cu121 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36479926 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /home/admin/anaconda3/envs/cv/lib/python3.10/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
# ...
